# %%
# What are the three stages to build the hypotheses or model in machine learning?

# %%
"Model building", "Model testing", "Applying the model"

# %%
# What is the standard approach to supervised learning?

# %%
by spliting the set of example into the 'training set' and the 'test set'

# %%
# What is Training set and Test set?

# %%
A set of data is used to discover the potentially predictive relationship known as 'Training set'.
A set of data is used to test the accuracy of the hypotheses generated by the learner known as 'Test set'

# %%
# What is the general principle of an ensemble method and what is bagging and boosting in ensemble method?

# %%
by 'cross validation' technique using 'training set' and 'test set'

# %%
# How can you avoid overfitting ?

# %%
When there is sufficient data 'Isotonic Regression' is used to prevent an overfitting issue.
